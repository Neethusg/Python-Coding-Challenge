# %% [markdown]
# 🎯 Challenge: Visualize Sales Data in 3D And 3D surface plot

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Data for sales in three regions over 12 months
months = np.arange(1, 13)
sales_north = np.random.randint(15000, 25000, 12)
sales_south = np.random.randint(12000, 22000, 12)
sales_west = np.random.randint(10000, 20000, 12)

# Combine data into a single dataset for easy plotting
sales_data = {
    "North": sales_north,
    "South": sales_south,
    "West": sales_west
}

# Create figure and 3D axis
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot for each region
ax.scatter(months, sales_north, np.full_like(months, 1), color='blue', label='North')
ax.scatter(months, sales_south, np.full_like(months, 2), color='green', label='South')
ax.scatter(months, sales_west, np.full_like(months, 3), color='red', label='West')

# Labels and title
ax.set_xlabel('Month')
ax.set_ylabel('Sales ($)')
ax.set_zlabel('Region')
ax.set_title('3D Sales Visualization by Region')

# Add legend
ax.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Data for sales in three regions over 12 months
months = np.arange(1, 13)
sales_north = np.random.randint(15000, 25000, 12)
sales_south = np.random.randint(12000, 22000, 12)
sales_west = np.random.randint(10000, 20000, 12)

# Generate meshgrid for the surface plot
X, Z = np.meshgrid(months, np.array([1, 2, 3]))  # X is months, Z is regions (1=North, 2=South, 3=West)

# Create corresponding Y values for each region
Y_north = sales_north
Y_south = sales_south
Y_west = sales_west

# Stack these values into a single array for the surface plot
Y = np.vstack([Y_north, Y_south, Y_west])

# Create figure and 3D axis
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Plot surface
ax.plot_surface(X, Z, Y, cmap='viridis', edgecolor='none')

# Labels and title
ax.set_xlabel('Month')
ax.set_ylabel('Region')
ax.set_zlabel('Sales ($)')
ax.set_title('3D Surface Plot of Sales by Region')

# Add a color bar
mappable = ax.plot_surface(X, Z, Y, cmap='viridis', edgecolor='none')
fig.colorbar(mappable, shrink=0.5, aspect=5)

# Show plot
plt.tight_layout()
plt.show()
